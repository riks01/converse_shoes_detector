# %% [markdown]
# <a href="https://colab.research.google.com/github/riks01/converse_shoes_detector/blob/main/yolov5/YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/yolo_v_5/
# Out:
# /content/drive/MyDrive/yolo_v_5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13092, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 13092 (delta 172), reused 197 (delta 138), pack-reused 12844
# Receiving objects: 100% (13092/13092), 13.14 MiB | 9.39 MiB/s, done.
# Resolving deltas: 100% (9002/9002), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-181-g8a19437 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.6/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %%
# Train YOLOv5s on data for 200 epochs
# !python train.py --img 240 --batch 16 --epochs 200 --data custom_data.yaml --weights yolov5s.pt --cache

# %%
#Detect
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.70 --source data/images/converse-run-star.jpg
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=data/images/converse-run-star.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirement "ipython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /content/drive/MyDrive/yolo_v_5/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v6.2-181-g8a19437 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# ...

# %%
# %cd yolov5/
# Out:
# /content/drive/MyDrive/yolo_v_5/yolov5

# %%
from IPython.display import Image
Image('runs/detect/exp6/converse-run-star.jpg')

# %%
# displaying the result of the training
Image('runs/train/exp2/results.png')
